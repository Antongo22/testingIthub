# %% [markdown]
# **install**

# %%
pip install pytest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pytest test.py --cov
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.0, pytest-8.3.3, pluggy-1.5.0
# rootdir: c:\Users\anton\Desktop\Полезные файлы\Учёба\ITHub\3 курс\1 семестр\Тестирование\кт4
# plugins: anyio-4.6.2.post1, cov-5.0.0, sugar-1.0.0
# collected 74 items
#
# test.py F...FF...FF..................................................... [ 86%]
# .........F                                                               [100%]
#
# ================================== FAILURES ===================================
# ____________________________ test_is_even[2-False] ____________________________
#
# number = 2, expected = False
#
#     @pytest.mark.parametrize("number, expected", [
#         (2, False), # провальный
#         (3, False),
#         (0, True),
#         (-2, True),
#         (-3, True)  # провальный
#     ])
#     def test_is_even(number, expected):
# >       assert is_even(number) == expected
# E       assert True == False
# ...
