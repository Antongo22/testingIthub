# %% [markdown]
# **install**

# %%
pip install pytest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pytest test_2.py --cov
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.0, pytest-8.3.3, pluggy-1.5.0
# rootdir: c:\Users\anton\Desktop\Полезные файлы\Учёба\ITHub\3 курс\1 семестр\Тестирование\кт2
# plugins: cov-5.0.0, sugar-1.0.0
# collected 1 item
#
# test_2.py F                                                              [100%]
#
# ================================== FAILURES ===================================
# ____________________________ test_superheroes_age _____________________________
#
#     def test_superheroes_age():
#         data = load_data('superhero_new.json')
#
#         for member in data['members']:
# >           assert member['age'] > 33, f"{member['name']} is not older than 33 years"
# E           AssertionError: Spider-Man is not older than 33 years
# E           assert 18 > 33
#
# test_2.py:12: AssertionError
#
# ---------- coverage: platform win32, python 3.13.0-final-0 -----------
# Name        Stmts   Miss  Cover
# ...

# %%
# !pytest test_1.py --cov
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.0, pytest-8.3.3, pluggy-1.5.0
# rootdir: c:\Users\anton\Desktop\Полезные файлы\Учёба\ITHub\3 курс\1 семестр\Тестирование\кт2
# plugins: cov-5.0.0, sugar-1.0.0
# collected 16 items
#
# test_1.py .FFFFFFFFFFFF.FF                                               [100%]
#
# ================================== FAILURES ===================================
# _______________________ TestTask1.test_final[82.8-48.0] _______________________
#
# self = <test_1.TestTask1 object at 0x000001963B9947D0>, expected = 82.8
# actual = 48.0
#
#     @pytest.mark.parametrize("expected, actual", expected_results())
#     def test_final(self, expected, actual):
# >       assert expected == actual
# E       assert 82.8 == 48.0
#
# test_1.py:12: AssertionError
# _______________________ TestTask1.test_final[55.2-44.0] _______________________
#
# ...
